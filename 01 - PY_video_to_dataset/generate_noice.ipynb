# %%
import os
from PIL import Image
import numpy as np
from scipy import ndimage

def simulate_abdominal_ultrasound(image):
    # Convert image to numpy array
    img_array = np.array(image).astype(float)
    
    # Normalize image
    img_array = (img_array - img_array.min()) / (img_array.max() - img_array.min())
    
    # Generate strong speckle noise
    speckle = np.random.rayleigh(scale=0.4, size=img_array.shape)
    
    # Apply speckle noise
    noisy_img = img_array * speckle
    
    # Add Gaussian noise
    gaussian_noise = np.random.normal(0, 0.2, img_array.shape)
    noisy_img += gaussian_noise
    
    # Simulate attenuation
    attenuation = np.linspace(1, 0.3, img_array.shape[0])[:, np.newaxis]
    noisy_img *= attenuation
    
    # Add strong vertical striping
    stripe_effect = np.sin(np.arange(img_array.shape[1]) * 0.2) * 0.15
    noisy_img += stripe_effect
    
    # Simulate acoustic shadows
    shadow_mask = np.random.rand(*img_array.shape) < 0.02
    shadow_mask = ndimage.binary_dilation(shadow_mask, iterations=3)
    noisy_img[shadow_mask] *= 0.3
    
    # Add bright reflections
    reflection_mask = np.random.rand(*img_array.shape) < 0.01
    reflection_mask = ndimage.binary_dilation(reflection_mask, iterations=2)
    noisy_img[reflection_mask] = 1.0
    
    # Clip values and rescale to 0-255
    noisy_img = np.clip(noisy_img, 0, 1)
    noisy_img = (noisy_img * 255).astype(np.uint8)
    
    # Apply slight Gaussian blur to simulate limited resolution
    noisy_img = ndimage.gaussian_filter(noisy_img, sigma=0.5)
    
    return Image.fromarray(noisy_img)

def process_images(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            with Image.open(os.path.join(input_folder, filename)) as img:
                img_gray = img.convert('L')
                ultrasound_img = simulate_abdominal_ultrasound(img_gray)
                output_path = os.path.join(output_folder, f"{filename}")
                ultrasound_img.save(output_path)
                print(f"Processed: {filename}")
# Usage
input_folder = "E:/Master IA/Practicas Empresa/Imagen/taza_dataset_angle/Feature_img/capturas"
output_folder = "E:/Master IA/Practicas Empresa/Imagen/taza_dataset_angle/Feature_img/noice"
process_images(input_folder, output_folder)
# Out:
# Processed: figura4_frame_0.png
# Processed: figura4_frame_1.png
# Processed: figura4_frame_10.png
# Processed: figura4_frame_100.png
# Processed: figura4_frame_101.png
# Processed: figura4_frame_102.png
# Processed: figura4_frame_103.png
# Processed: figura4_frame_104.png
# Processed: figura4_frame_105.png
# Processed: figura4_frame_106.png
# Processed: figura4_frame_107.png
# Processed: figura4_frame_108.png
# Processed: figura4_frame_109.png
# Processed: figura4_frame_11.png
# Processed: figura4_frame_110.png
# Processed: figura4_frame_111.png
# Processed: figura4_frame_112.png
# Processed: figura4_frame_113.png
# Processed: figura4_frame_114.png
# Processed: figura4_frame_115.png
# Processed: figura4_frame_116.png
# Processed: figura4_frame_117.png
# Processed: figura4_frame_118.png
# Processed: figura4_frame_119.png
# Processed: figura4_frame_12.png
# Processed: figura4_frame_120.png
# Processed: figura4_frame_121.png
# Processed: figura4_frame_122.png
# Processed: figura4_frame_123.png
# Processed: figura4_frame_124.png
# Processed: figura4_frame_125.png
# Processed: figura4_frame_126.png
# Processed: figura4_frame_127.png
# Processed: figura4_frame_128.png
# Processed: figura4_frame_129.png
# Processed: figura4_frame_13.png
# Processed: figura4_frame_130.png
# Processed: figura4_frame_131.png
# Processed: figura4_frame_132.png
# Processed: figura4_frame_133.png
# Processed: figura4_frame_134.png
# Processed: figura4_frame_135.png
# Processed: figura4_frame_136.png
# Processed: figura4_frame_137.png
# Processed: figura4_frame_138.png
# Processed: figura4_frame_139.png
# Processed: figura4_frame_14.png
# Processed: figura4_frame_140.png
# Processed: figura4_frame_141.png
# Processed: figura4_frame_142.png
# Processed: figura4_frame_143.png
# Processed: figura4_frame_144.png
# Processed: figura4_frame_145.png
# Processed: figura4_frame_146.png
# Processed: figura4_frame_147.png
# Processed: figura4_frame_148.png
# Processed: figura4_frame_15.png
# Processed: figura4_frame_16.png
# Processed: figura4_frame_17.png
# Processed: figura4_frame_18.png
# Processed: figura4_frame_19.png
# Processed: figura4_frame_2.png
# Processed: figura4_frame_20.png
# Processed: figura4_frame_21.png
# Processed: figura4_frame_22.png
# Processed: figura4_frame_23.png
# Processed: figura4_frame_24.png
# Processed: figura4_frame_25.png
# Processed: figura4_frame_26.png
# Processed: figura4_frame_27.png
# Processed: figura4_frame_28.png
# Processed: figura4_frame_29.png
# Processed: figura4_frame_3.png
# Processed: figura4_frame_30.png
# Processed: figura4_frame_31.png
# Processed: figura4_frame_32.png
# Processed: figura4_frame_33.png
# Processed: figura4_frame_34.png
# Processed: figura4_frame_35.png
# Processed: figura4_frame_36.png
# Processed: figura4_frame_37.png
# Processed: figura4_frame_38.png
# Processed: figura4_frame_39.png
# Processed: figura4_frame_4.png
# Processed: figura4_frame_40.png
# Processed: figura4_frame_41.png
# Processed: figura4_frame_42.png
# Processed: figura4_frame_43.png
# Processed: figura4_frame_44.png
# Processed: figura4_frame_45.png
# Processed: figura4_frame_46.png
# Processed: figura4_frame_47.png
# Processed: figura4_frame_48.png
# Processed: figura4_frame_49.png
# Processed: figura4_frame_5.png
# Processed: figura4_frame_50.png
# Processed: figura4_frame_51.png
# Processed: figura4_frame_52.png
# Processed: figura4_frame_53.png
# Processed: figura4_frame_54.png
# Processed: figura4_frame_55.png
# Processed: figura4_frame_56.png
# Processed: figura4_frame_57.png
# Processed: figura4_frame_58.png
# Processed: figura4_frame_59.png
# Processed: figura4_frame_6.png
# Processed: figura4_frame_60.png
# Processed: figura4_frame_61.png
# Processed: figura4_frame_62.png
# Processed: figura4_frame_63.png
# Processed: figura4_frame_64.png
# Processed: figura4_frame_65.png
# Processed: figura4_frame_66.png
# Processed: figura4_frame_67.png
# Processed: figura4_frame_68.png
# Processed: figura4_frame_69.png
# Processed: figura4_frame_7.png
# Processed: figura4_frame_70.png
# Processed: figura4_frame_71.png
# Processed: figura4_frame_72.png
# Processed: figura4_frame_73.png
# Processed: figura4_frame_74.png
# Processed: figura4_frame_75.png
# Processed: figura4_frame_76.png
# Processed: figura4_frame_77.png
# Processed: figura4_frame_78.png
# Processed: figura4_frame_79.png
# Processed: figura4_frame_8.png
# Processed: figura4_frame_80.png
# Processed: figura4_frame_81.png
# Processed: figura4_frame_82.png
# Processed: figura4_frame_83.png
# Processed: figura4_frame_84.png
# Processed: figura4_frame_85.png
# Processed: figura4_frame_86.png
# Processed: figura4_frame_87.png
# Processed: figura4_frame_88.png
# Processed: figura4_frame_89.png
# Processed: figura4_frame_9.png
# Processed: figura4_frame_90.png
# Processed: figura4_frame_91.png
# Processed: figura4_frame_92.png
# Processed: figura4_frame_93.png
# Processed: figura4_frame_94.png
# Processed: figura4_frame_95.png
# Processed: figura4_frame_96.png
# Processed: figura4_frame_97.png
# Processed: figura4_frame_98.png
# Processed: figura4_frame_99.png
# Processed: figura5_frame_0.png
# Processed: figura5_frame_1.png
# Processed: figura5_frame_10.png
# Processed: figura5_frame_100.png
# Processed: figura5_frame_101.png
# Processed: figura5_frame_102.png
# Processed: figura5_frame_103.png
# Processed: figura5_frame_104.png
# Processed: figura5_frame_105.png
# Processed: figura5_frame_106.png
# Processed: figura5_frame_107.png
# Processed: figura5_frame_108.png
# Processed: figura5_frame_109.png
# Processed: figura5_frame_11.png
# Processed: figura5_frame_110.png
# Processed: figura5_frame_111.png
# Processed: figura5_frame_112.png
# Processed: figura5_frame_113.png
# Processed: figura5_frame_114.png
# Processed: figura5_frame_115.png
# Processed: figura5_frame_116.png
# Processed: figura5_frame_117.png
# Processed: figura5_frame_118.png
# Processed: figura5_frame_119.png
# Processed: figura5_frame_12.png
# Processed: figura5_frame_120.png
# Processed: figura5_frame_121.png
# Processed: figura5_frame_122.png
# Processed: figura5_frame_123.png
# Processed: figura5_frame_124.png
# Processed: figura5_frame_125.png
# Processed: figura5_frame_126.png
# Processed: figura5_frame_127.png
# Processed: figura5_frame_128.png
# Processed: figura5_frame_129.png
# Processed: figura5_frame_13.png
# Processed: figura5_frame_130.png
# Processed: figura5_frame_131.png
# Processed: figura5_frame_132.png
# Processed: figura5_frame_133.png
# Processed: figura5_frame_134.png
# Processed: figura5_frame_135.png
# Processed: figura5_frame_136.png
# Processed: figura5_frame_137.png
# Processed: figura5_frame_138.png
# Processed: figura5_frame_139.png
# Processed: figura5_frame_14.png
# Processed: figura5_frame_140.png
# Processed: figura5_frame_141.png
# Processed: figura5_frame_142.png
# Processed: figura5_frame_143.png
# Processed: figura5_frame_144.png
# Processed: figura5_frame_145.png
# Processed: figura5_frame_146.png
# Processed: figura5_frame_147.png
